# %% [markdown]
# # **Codveda Technologies Internship For ML**
#
# #Task 1: Data Preprocessing for Machine Learning:
# **Intern**-*MD.Rakibul Hossain*
#
# **Dataset**-*stockprice*.*csv*
#
# **Objectives**:
#
# *   Handle missing data (e.g., filling with mean/median,
# dropping).
# *   Encode categorical variables (e.g., using one-hot
# encoding or label encoding).
#
# *   Normalize or standardize numerical features.
# *   Split the dataset into training and testing sets.
#
# *   Tools: Python, pandas, scikit-learn.
#
# **Description**: Preprocess a raw dataset to make it ready
# for machine learning.

# %% [markdown]
# # 1. Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2.Import the relevant libraries

# %%
#python libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split #Model
from sklearn.preprocessing import StandardScaler, OneHotEncoder #Preprocessing
from sklearn.impute import SimpleImputer

# %% [markdown]
# # 3.Load Dataset

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset/2) Stock Prices Data Set.csv') # Load Dataset

# %% [markdown]
# # 4.Head of dataset

# %%
df.head(20)
# Out:
#    symbol        date      open      high       low     close    volume
# 0     AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1    AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2     AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3    ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4     ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391
# 5     ABT  2014-01-02   38.0900   38.4000   38.0000   38.2300   4967472
# 6     ACN  2014-01-02   81.5000   81.9200   81.0900   81.1300   2405384
# 7    ADBE  2014-01-02   59.0600   59.5300   58.9400   59.2900   2746370
# 8     ADI  2014-01-02   49.5200   49.7500   49.0400   49.2800   2799092
# 9     ADM  2014-01-02   43.2200   43.2900   42.7900   42.9900   2753765
# 10    ADP  2014-01-02   80.1700   80.4500   79.3800   79.8600   1965869
# 11   ADSK  2014-01-02   49.3300   49.7400   48.8800   49.2500   2488043
# ...

# %% [markdown]
# * 'symbol' and 'date' are categorical/object columns; others are numeric.

# %% [markdown]
# # 5.Dataset Information

# %%
#view dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497472 entries, 0 to 497471
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   symbol  497472 non-null  object
#  1   date    497472 non-null  object
#  2   open    497461 non-null  float64
#  3   high    497464 non-null  float64
#  4   low     497464 non-null  float64
#  5   close   497472 non-null  float64
#  6   volume  497472 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 26.6+ MB

# %% [markdown]
# * The dataset contains 4,97,472 rows and 7 columns.

# %% [markdown]
# # 6.Check Null Values of Dataset

# %%
# Check missing values
print("\nMissing values per column:")
df.isnull().sum()
# Out:
# Missing values per column:
# symbol     0
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# dtype: int64

# %% [markdown]
# * Heare we can see that three columns has null values
# * dataset contains 11 missing values in 'open', 8 in 'high' and 8 in 'low'.

# %% [markdown]
# # 7.Finding Mean value of Column 'open'

# %%
df.open.mean()
# Out:
# np.float64(86.35227481611624)

# %% [markdown]
#  Fill missing numeric column with mean

# %%
# Fill missing numeric columns with mean
df.open.fillna(df.open.mean(),inplace=True)
# Out:
# <ipython-input-36-5003999dca80>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.open.fillna(df.open.mean(),inplace=True)

# %% [markdown]
# # 8.Finding Mean value of Column 'high'
# Fill missing numeric column with mean

# %%
df.high.mean()
df.high.fillna(df.high.mean(),inplace=True) # Fill missing numeric columns with mean
# Out:
# <ipython-input-37-c6c49a7ba557>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.high.fillna(df.high.mean(),inplace=True)

# %% [markdown]
# # 9.Finding Mean value of Column 'low'
# Fill missing numeric column with mean

# %%
df.low.mean()
df.low.fillna(df.low.mean(),inplace=True) # Fill missing numeric columns with mean
# Out:
# <ipython-input-38-92f6a9877b2e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.low.fillna(df.low.mean(),inplace=True)

# %% [markdown]
# # 10.Verify no missing values remain

# %%
df.isnull().sum()
# Out:
# symbol    0
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %% [markdown]
# * now there is no null values

# %% [markdown]
# # 11.Describe the Dataset

# %%
# Basic stats
df.describe()
# Out:
#                 open           high            low          close  \
# count  497472.000000  497472.000000  497472.000000  497472.000000
# mean       86.352275      87.132562      85.552467      86.369082
# std       101.470106     102.311239     100.570148     101.472407
# min         1.620000       1.690000       1.500000       1.590000
# 25%        41.690000      42.090000      41.280000      41.703750
# 50%        64.970000      65.560000      64.360000      64.980000
# 75%        98.410000      99.230000      97.580000      98.420000
# max      2044.000000    2067.990000    2035.110000    2049.000000
#
#              volume
# count  4.974720e+05
# mean   4.253611e+06
# std    8.232139e+06
# min    0.000000e+00
# 25%    1.080166e+06
# 50%    2.084896e+06
# 75%    4.271928e+06
# max    6.182376e+08

# %% [markdown]
# # 12.Drooping Column 'volume' cause it's output data

# %%
# Drooping volume
x=df.drop(columns=['volume'],axis=1) #Separate Features and Target

# %% [markdown]
# y remains column 'volume'

# %%
y= df['volume'] #Target colomn

# %% [markdown]
# check x data

# %%
x
# Out:
#        symbol        date      open      high       low     close
# 0         AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600
# 1        AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185
# 2         AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400
# 3        ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800
# 4         ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900
# ...       ...         ...       ...       ...       ...       ...
# 497467    XYL  2017-12-29   68.5300   68.8000   67.9200   68.2000
# 497468    YUM  2017-12-29   82.6400   82.7100   81.5900   81.6100
# 497469    ZBH  2017-12-29  121.7500  121.9500  120.6200  120.6700
# 497470   ZION  2017-12-29   51.2800   51.5500   50.8100   50.8300
# 497471    ZTS  2017-12-29   72.5500   72.7600   72.0400   72.0400
#
# [497472 rows x 6 columns]

# %% [markdown]
# check y data

# %%
y
# Out:
# 0          8998943
# 1         58791957
# 2           542711
# 3          4569061
# 4          1148391
#             ...
# 497467     1046677
# 497468     1347613
# 497469     1023624
# 497470     1261916
# 497471     1704122
# Name: volume, Length: 497472, dtype: int64

# %% [markdown]
# # 13.Column 'symbol' has unique values

# %%
# View unique symbols (categorical variable)
x.symbol.unique()
# Out:
# array(['AAL', 'AAPL', 'AAP', 'ABBV', 'ABC', 'ABT', 'ACN', 'ADBE', 'ADI',
#        'ADM', 'ADP', 'ADSK', 'ADS', 'AEE', 'AEP', 'AES', 'AET', 'AFL',
#        'AGN', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK',
#        'ALLE', 'ALL', 'ALXN', 'AMAT', 'AMD', 'AME', 'AMGN', 'AMG', 'AMP',
#        'AMT', 'AMZN', 'ANDV', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APC',
#        'APD', 'APH', 'ARE', 'ARNC', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK',
#        'AXP', 'AYI', 'AZO', 'A', 'BAC', 'BAX', 'BA', 'BBT', 'BBY', 'BDX',
#        'BEN', 'BF.B', 'BIIB', 'BK', 'BLK', 'BLL', 'BMY', 'BRK.B', 'BSX',
#        'BWA', 'BXP', 'CAG', 'CAH', 'CAT', 'CA', 'CBG', 'CBOE', 'CBS',
#        'CB', 'CCI', 'CCL', 'CDNS', 'CELG', 'CERN', 'CF', 'CHD', 'CHK',
#        'CHRW', 'CHTR', 'CINF', 'CI', 'CLX', 'CL', 'CMA', 'CMCSA', 'CME',
#        'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COL', 'COO',
#        'COP', 'COST', 'COTY', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS', 'CTL',
# ...

# %% [markdown]
# # 14.Shape of dataset

# %%
df.shape # Shape of dataset
# Out:
# (497472, 7)

# %% [markdown]
# # 15.Encode categorical variable

# %% [markdown]
# * We apply One-Hot Encoding to the 'symbol' categorical column.

# %%
# One-hot encode 'symbol' column
df_encode=pd.get_dummies(df['symbol'])

# %%
df_encode # Preview new columns
# Out:
#             A    AAL    AAP   AAPL   ABBV    ABC    ABT    ACN   ADBE    ADI  \
# 0       False   True  False  False  False  False  False  False  False  False
# 1       False  False  False   True  False  False  False  False  False  False
# 2       False  False   True  False  False  False  False  False  False  False
# 3       False  False  False  False   True  False  False  False  False  False
# 4       False  False  False  False  False   True  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 497467  False  False  False  False  False  False  False  False  False  False
# 497468  False  False  False  False  False  False  False  False  False  False
# 497469  False  False  False  False  False  False  False  False  False  False
# 497470  False  False  False  False  False  False  False  False  False  False
# 497471  False  False  False  False  False  False  False  False  False  False
#
# ...

# %% [markdown]
# * drop orginal columns 'symbol' and 'date'

# %%
x=x.drop(columns=['symbol','date'],axis=1) #Droping orginal columns 'symbol' and 'date'

# %%
x=pd.concat([x,df_encode],axis=1)

# %%
x
# Out:
#             open      high       low     close      A    AAL    AAP   AAPL  \
# 0        25.0700   25.8200   25.0600   25.3600  False   True  False  False
# 1        79.3828   79.5756   78.8601   79.0185  False  False  False   True
# 2       110.3600  111.8800  109.2900  109.7400  False  False   True  False
# 3        52.1200   52.3300   51.5200   51.9800  False  False  False  False
# 4        70.1100   70.2300   69.4800   69.8900  False  False  False  False
# ...          ...       ...       ...       ...    ...    ...    ...    ...
# 497467   68.5300   68.8000   67.9200   68.2000  False  False  False  False
# 497468   82.6400   82.7100   81.5900   81.6100  False  False  False  False
# 497469  121.7500  121.9500  120.6200  120.6700  False  False  False  False
# 497470   51.2800   51.5500   50.8100   50.8300  False  False  False  False
# 497471   72.5500   72.7600   72.0400   72.0400  False  False  False  False
#
# ...

# %% [markdown]
# # 16.Scaling dataset

# %% [markdown]
# * We apply standard scaling to numeric features.

# %%
scaler=StandardScaler() #scaling

# %%
#scaling numerical columns
numeric_cols = ['open', 'high', 'low', 'close'] # Removed 'volume' as it's the target variable
x[numeric_cols] = scaler.fit_transform(x[numeric_cols]) # Scaling on 'x' instead of 'df_encode'

x.head()
# Out:
#        open      high       low     close      A    AAL    AAP   AAPL   ABBV  \
# 0 -0.603945 -0.599276 -0.601496 -0.601239  False   True  False  False  False
# 1 -0.068685 -0.073863 -0.066544 -0.072439  False  False  False   True  False
# 2  0.236599  0.241884  0.236030  0.230318  False  False   True  False  False
# 3 -0.337363 -0.340164 -0.338396 -0.338901  False  False  False  False   True
# 4 -0.160070 -0.165207 -0.159814 -0.162400  False  False  False  False  False
#
#      ABC  ...     XL   XLNX    XOM   XRAY    XRX    XYL    YUM    ZBH   ZION  \
# 0  False  ...  False  False  False  False  False  False  False  False  False
# 1  False  ...  False  False  False  False  False  False  False  False  False
# 2  False  ...  False  False  False  False  False  False  False  False  False
# 3  False  ...  False  False  False  False  False  False  False  False  False
# 4   True  ...  False  False  False  False  False  False  False  False  False
#
#      ZTS
# 0  False
# 1  False
# ...

# %% [markdown]
# # 17.Split into Training and Testing Sets

# %% [markdown]
# * We split features and target variable into training and testing sets.

# %%
#Split Dataset
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
print("Training set shape:",x_train.shape)
print("Testing set shape:",x_test.shape)
# Out:
# Training set shape: (373104, 509)
# Testing set shape: (124368, 509)

# %% [markdown]
# **Conclusion**
#
# In this task, we:
#
# * Handled missing data
# * Encoded categorical variables
# Transformed date column
# * Normalized numerical features
# *Split dataset into training and testing sets
# *The dataset is now ready for machine learning modeling.
